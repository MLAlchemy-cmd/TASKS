# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("books.xlsx")

# %% [markdown]
# Data Prepocessing

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPrÌ©           4.57   439785960  9780000000000
# 1  J.K. Rowling/Mary GrandPrÌ©           4.49   439358078  9780000000000
# 2                 J.K. Rowling           4.42   439554896  9780000000000
# 3  J.K. Rowling/Mary GrandPrÌ©           4.56  043965548X  9780000000000
# 4  J.K. Rowling/Mary GrandPrÌ©           4.78   439682584  9780000000000
#
#   language_code num_pages  ratings_count  text_reviews_count  \
# 0           eng       652        2095690               27591
# ...

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793647e+04          541.859531
# std    13093.358023   1.124794e+05         2576.175586
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           46.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
df.isnull().sum()
# Out:
# bookID                    0
# title                     0
# authors                   0
# average_rating            0
# isbn                      0
# isbn13                    0
# language_code             0
# num_pages                 0
# ratings_count             0
# text_reviews_count        0
# publication_date          0
# publisher                 0
# Unnamed: 12           11124
# dtype: int64

# %%
print(df.shape)
# Out:
# (11127, 13)

# %%
df = df.drop("isbn13",axis =1)

# %%
print(df.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn language_code  \
# 0  J.K. Rowling/Mary GrandPrÌ©           4.57   439785960           eng
# 1  J.K. Rowling/Mary GrandPrÌ©           4.49   439358078           eng
# 2                 J.K. Rowling           4.42   439554896           eng
# 3  J.K. Rowling/Mary GrandPrÌ©           4.56  043965548X           eng
# 4  J.K. Rowling/Mary GrandPrÌ©           4.78   439682584           eng
#
#   num_pages  ratings_count  text_reviews_count     publication_date  \
# 0       652        2095690               27591  2006-09-16 00:00:00
# ...

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# bookID                 int64
# title                 object
# authors               object
# average_rating        object
# isbn                  object
# language_code         object
# num_pages             object
# ratings_count          int64
# text_reviews_count     int64
# publication_date      object
# publisher             object
# Unnamed: 12           object
# dtype: object

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'], errors='coerce')

# %%
print(df.dtypes)

# Extract the year from 'publication_date'
df['publication_year'] = df['publication_date'].dt.year
# Out:
# bookID                         int64
# title                         object
# authors                       object
# average_rating                object
# isbn                          object
# language_code                 object
# num_pages                     object
# ratings_count                  int64
# text_reviews_count             int64
# publication_date      datetime64[ns]
# publisher                     object
# Unnamed: 12                   object
# dtype: object

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn language_code  \
# 0  J.K. Rowling/Mary GrandPrÌ©           4.57   439785960           eng
# 1  J.K. Rowling/Mary GrandPrÌ©           4.49   439358078           eng
# 2                 J.K. Rowling           4.42   439554896           eng
# 3  J.K. Rowling/Mary GrandPrÌ©           4.56  043965548X           eng
# 4  J.K. Rowling/Mary GrandPrÌ©           4.78   439682584           eng
#
#   num_pages  ratings_count  text_reviews_count publication_date  \
# 0       652        2095690               27591       2006-09-16
# ...

# %%
df.tail()
# Out:
#        bookID                                             title  \
# 11122   45631  Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                       You Bright and Risen Angels
# 11124   45634                   The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                       Poor People
# 11126   45641                       Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 11122  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 11123                                William T. Vollmann           4.08
# 11124                                William T. Vollmann           3.96
# 11125                                William T. Vollmann           3.72
# 11126                                         Mark Twain           3.91
#
#              isbn language_code num_pages  ratings_count  text_reviews_count  \
# ...

# %%
df = df.drop('Unnamed: 12',axis =1)

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'language_code',
#        'num_pages', 'ratings_count', 'text_reviews_count', 'publication_date',
#        'publisher', 'publication_year'],
#       dtype='object')

# %%
unique_authors_count = len(df['authors'].unique())
unique_authors_count
# Out:
# 6643

# %%
unique_publisher_count = len(df['publisher'].unique())
unique_publisher_count
# Out:
# 2293

# %%
df.loc[df['authors'] == 'David E. Smith (Turgon of TheOneRing.net', 'average_rating'] = 3.58

# %%
df.loc[df['authors'] == 'David E. Smith (Turgon of TheOneRing.net', 'ratings_count'] = 26
df.loc[df['authors'] == 'David E. Smith (Turgon of TheOneRing.net', 'text_reviews_count'] = 4
df.loc[df['authors'] == 'David E. Smith (Turgon of TheOneRing.net', 'publisher'] = 'Cold Spring Press'
df.loc[df['authors'] == 'David E. Smith (Turgon of TheOneRing.net', 'publication_year'] = 2004

# %%
df.loc[df['bookID'] == 22128, 'average_rating'] = 3.63
df.loc[df['bookID'] == 22128, 'ratings_count'] = 38
df.loc[df['bookID'] == 22128, 'text_reviews_count'] = 4
df.loc[df['bookID'] == 22128, 'publication_date'] = 15-1-1999
df.loc[df['bookID'] == 22128, 'publication_year'] = 1999
df.loc[df['bookID'] == 22128, 'publisher'] = "Huntington House Publishers"

# %%
df.loc[df['bookID'] == 34889, 'average_rating'] = 0
df.loc[df['bookID'] == 34889, 'ratings_count'] = 0
df.loc[df['bookID'] == 34889, 'text_reviews_count'] = 0
df.loc[df['bookID'] == 34889, 'publication_date'] = 1-5-1977
df.loc[df['bookID'] == 34889, 'publication_year'] = 1977

df.loc[df['bookID'] == 34889, 'publisher'] = "Brown Son & Ferguson Ltd."

# %% [markdown]
# Predicting the fame of each author

# %%
author_fame = df.groupby('authors').agg({
    'average_rating' : 'mean',
    'ratings_count': 'sum',
    'text_reviews_count' : 'sum'
}
)

# %%
author_fame["fame_score"] = (
                             author_fame["average_rating"]*0.4 +
                             author_fame['ratings_count'] * 0.2 +
                             author_fame['text_reviews_count'] * 0.1)

# %%
sorted_authors = author_fame.sort_values(by='fame_score', ascending=False)
print(sorted_authors)
# Out:
#                              average_rating  ratings_count  \
# authors
# J.K. Rowling/Mary GrandPrÌ©        4.548333        8923980
# J.R.R. Tolkien                     4.395882        4776638
# Stephenie Meyer                    3.590000        4597666
# Dan Brown                          3.824167        4135380
# Nicholas Sparks                    3.994286        3048149
# ...                                     ...            ...
# James Craig Holte                  0.000000              0
# Dobrica Eri€à                      0.000000              0
# Dan Hitt/James Beckett III         0.000000              0
# Apollodorus/Richard Wagner         0.000000              0
# J. Martin Evans                    0.000000              0
#
#                              text_reviews_count    fame_score
# authors
# J.K. Rowling/Mary GrandPrÌ©              128006  1.797598e+06
# J.R.R. Tolkien                            49090  9.602384e+05
# ...

# %% [markdown]
# Prolific publisher

# %%
books_per_publisher = df['publisher'].value_counts()

# %%
print(books_per_publisher)
# Out:
# Vintage                        318
# Penguin Books                  261
# Penguin Classics               184
# Mariner Books                  150
# Ballantine Books               144
#                               ...
# University of Calgary Press      1
# Marlowe & Company                1
# University Press of America      1
# Abstract Studio                  1
# Sounds True                      1
# Name: publisher, Length: 2292, dtype: int64

# %% [markdown]
# Best Seller

# %%
df['score'] = 0.7 * df['average_rating'] + 0.3 * df['ratings_count']
df_sorted = df.sort_values(by='score', ascending=False)
print("Sorted DataFrame based on score:")
print(df_sorted)
# Out:
# Sorted DataFrame based on score:
#        bookID                                              title  \
# 10340   41865                            Twilight (Twilight  #1)
# 1697     5907                The Hobbit  or There and Back Again
# 1462     5107                             The Catcher in the Rye
# 307       960               Angels & Demons (Robert Langdon  #1)
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...       ...                                                ...
# 2532     9337  How To Meditate: An Anthology Of Talks On Medi...
# 6880    25903  I'll Be Home Before Midnight and I Won't Get P...
# 6383    24010         Laguna  I Love You: The Best of "Our Town"
# 987      3351           Open City 6: The Only Woman He Ever Left
# 9335    36946      Random House Crossword Mega Omnibus  Volume 1
#
#                                                  authors average_rating  \
# 10340                                    Stephenie Meyer           3.59
# ...

# %% [markdown]
# Data Visualization

# %%
top_publishers = df['publisher'].value_counts().nlargest(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_publishers.index, y=top_publishers.values)
plt.title('Top 10 Publishers by Book Count')
plt.xlabel('Publisher')
plt.ylabel('Book Count')
plt.xticks(rotation=45)
plt.show()

# %%
top_authors = df['authors'].value_counts().nlargest(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_authors.index, y=top_authors.values)
plt.title('Top 10 Authors by Book Count')
plt.xlabel('Author')
plt.ylabel('Book Count')
plt.xticks(rotation=45, ha='right')  # Adjust rotation for better readability
plt.show()

# %%
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Convert all values in the 'title' column to strings
df['title'] = df['title'].astype(str)

# Tokenize the words in the 'title' column
all_words = ' '.join(df['title']).lower().split()

# Use Counter to count the occurrences of each word
word_counts = Counter(all_words)

# Extract the most common words and their frequencies
top_words = word_counts.most_common(70)

# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(top_words))

# Plot the WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Most Common Words in Titles')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))

mean_ratings = df.groupby('authors')['average_rating'].mean().reset_index()

sns.barplot(x='authors', y='average_rating', data=mean_ratings, palette='viridis')
plt.title('Mean Average Rating for Each Author')
plt.xlabel('Author')
plt.ylabel('Mean Average Rating')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 141 (\x8d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 143 (\x8f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 157 (\x9d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 144 (\x90) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame has columns 'authors' and 'average_rating'
plt.figure(figsize=(6, 5))

# Calculate the mean of average ratings for each author
mean_ratings = df.groupby('authors')['average_rating'].mean().reset_index()

# Select the top 5 authors with the highest mean ratings
top_authors = mean_ratings.nlargest(30, 'average_rating')

# Create a bar plot for the top 5 authors
sns.barplot(x='authors', y='average_rating', data=top_authors, palette='viridis')
plt.title('Top 35 Authors with the Highest Mean Average Ratings')
plt.xlabel('Author')
plt.ylabel('Mean Average Rating')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
correlation_matrix = df[['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
# Out:
# <ipython-input-68-d047f655ded6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count']].corr()

# %%
sns.countplot(x='language_code', data=df, palette='Set3')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
 #  Building an Recommendation system - Content-based filtering

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn language_code  \
# 0  J.K. Rowling/Mary GrandPrÌ©           4.57   439785960           eng
# 1  J.K. Rowling/Mary GrandPrÌ©           4.49   439358078           eng
# 2                 J.K. Rowling           4.42   439554896           eng
# 3  J.K. Rowling/Mary GrandPrÌ©           4.56  043965548X           eng
# 4  J.K. Rowling/Mary GrandPrÌ©           4.78   439682584           eng
#
#   num_pages  ratings_count  text_reviews_count     publication_date  \
# 0       652        2095690               27591  2006-09-16 00:00:00
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
content_cols = ['title', 'authors', 'average_rating', 'language_code', 'num_pages', 'ratings_count',
                'text_reviews_count', 'publication_date', 'publisher', 'publication_year']

# %%
content_df = df[content_cols].dropna()

# %%
content_df['features'] = content_df.apply(lambda row: ' '.join(row.map(str)), axis=1)

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(content_df['features'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(book_title, cosine_sim_matrix, df, top_n=5):
    idx = df[df['title'] == book_title].index[0]
    sim_scores = list(enumerate(cosine_sim_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n + 1]
    book_indices = [i[0] for i in sim_scores]
    return df['title'].iloc[book_indices]

# %%
selected_book = 'Harry Potter and the Half-Blood Prince (Harry Potter  #6)'
recommendations = get_recommendations(selected_book, cosine_sim, content_df)
print(recommendations)
# Out:
# 615     Harry Potter and the Half-Blood Prince (Harry ...
# 4       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 1       Harry Potter and the Order of the Phoenix (Har...
# 3       Harry Potter and the Prisoner of Azkaban (Harr...
# 4416    Harry Potter and the Chamber of Secrets (Harry...
# Name: title, dtype: object
